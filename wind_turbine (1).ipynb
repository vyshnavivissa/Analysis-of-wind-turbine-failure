# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'Wind_Turbine.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26281 entries, 0 to 26280
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           26281 non-null  object
#  1   Wind_speed                     25759 non-null  float64
#  2   Power                          25763 non-null  float64
#  3   Nacelle_ambient_temperature    25756 non-null  float64
#  4   Generator_bearing_temperature  25756 non-null  float64
#  5   Gear_oil_temperature           25761 non-null  float64
#  6   Ambient_temperature            25764 non-null  float64
#  7   Rotor_Speed                    25764 non-null  float64
#  8   Nacelle_temperature            25756 non-null  float64
#  9   Bearing_temperature            25756 non-null  float64
#  10  Generator_speed                25762 non-null  float64
#  11  Yaw_angle                      25756 non-null  float64
#  12  Wind_direction                 25756 non-null  float64
#  13  Wheel_hub_temperature          25756 non-null  float64
#  14  Gear_box_inlet_temperature     25756 non-null  float64
#  15  Failure_status                 26281 non-null  object
# dtypes: float64(14), object(2)
# memory usage: 3.2+ MB

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.describe()
# Out:
#                       date    Wind_speed         Power  \
# count                26281  25759.000000  25763.000000
# mean   2023-07-02 12:00:00     11.777470    394.141905
# min    2022-01-01 00:00:00      0.007881   -338.346253
# 25%    2022-10-01 18:00:00      7.334042     72.969107
# 50%    2023-07-02 12:00:00     11.614141    248.957796
# 75%    2024-04-01 06:00:00     15.890762    610.788454
# max    2024-12-31 00:00:00     38.176200   2288.232291
# std                    NaN      5.944046    449.959176
#
#        Nacelle_ambient_temperature  Generator_bearing_temperature  \
# count                 25756.000000                   25756.000000
# mean                      9.995125                      17.991323
# min                     -11.182339                      -8.724242
# 25%                      -0.399825                       7.938018
# 50%                      10.045773                      17.958251
# 75%                      20.344801                      27.983161
# max                      31.642088                      47.244606
# std                      10.777356                      11.184316
#
#        Gear_oil_temperature  Ambient_temperature   Rotor_Speed  \
# count          25761.000000         25764.000000  25764.000000
# mean              15.523561            10.535898     58.866540
# min               -8.963339           -11.182339     -9.706307
# 25%                4.877761            -0.318842     36.615698
# 50%               15.178296            10.256434     58.061232
# 75%               25.410180            20.608845     79.447768
# max               69.842754            63.904769    193.255298
# std               12.227037            12.009792     30.225918
#
#        Nacelle_temperature  Bearing_temperature  Generator_speed  \
# count         25756.000000         25756.000000     25762.000000
# mean             14.002058            16.012173        70.689381
# min             -11.409870           -11.421907       -28.140172
# 25%               3.856342             6.061836        43.511730
# 50%              13.989083            16.047325        69.517202
# 75%              24.153817            25.996892        95.578092
# max              38.046144            45.946883       239.352527
# std              10.959749            11.166944        37.969147
#
#           Yaw_angle  Wind_direction  Wheel_hub_temperature  \
# count  25756.000000    25756.000000           25756.000000
# mean       0.509362      180.204385              16.985201
# min      -89.973673        0.019102              -7.196413
# 25%      -44.000743       91.156882               6.836108
# 50%        0.113390      181.112856              16.931774
# 75%       45.542359      269.085910              27.165080
# max       89.980053      359.996412              41.022313
# std       51.867455      103.532054              10.952033
#
#        Gear_box_inlet_temperature
# count                25756.000000
# mean                    14.962366
# min                     -8.733161
# 25%                      4.733503
# 50%                     15.026247
# 75%                     25.080284
# max                     39.312146
# std                     10.963863

# %% [markdown]
# # statistical values of numeric columns

# %%
numeric_columns=df.select_dtypes(include=['number'])

# %%
for col in numeric_columns:
    print(f"\nColumn: {col}")
    print("Mean:", df[col].mean())
    print("Variance:", df[col].var())
    print("Skewness:", df[col].skew())
    print("Kurtosis:", df[col].kurt())
# Out:
# Column: Wind_speed
# Mean: 11.777469747650475
# Variance: 35.33168086362799
# Skewness: 0.7770166060020003
# Kurtosis: 2.3207088012016297
#
# Column: Power
# Mean: 394.14190506306005
# Variance: 202463.26035538886
# Skewness: 1.5091717268763358
# Kurtosis: 2.6276096618534437
#
# Column: Nacelle_ambient_temperature
# Mean: 9.995125216327544
# Variance: 116.15140100453489
# Skewness: 0.0015433617879166848
# Kurtosis: -1.3982796445298804
#
# Column: Generator_bearing_temperature
# Mean: 17.991322767500417
# Variance: 125.08892788986454
# Skewness: 0.005980462416840355
# Kurtosis: -1.2102453213090234
#
# Column: Gear_oil_temperature
# Mean: 15.52356136072118
# Variance: 149.50043506740306
# Skewness: 0.7898109771366386
# Kurtosis: 2.057661994474427
#
# Column: Ambient_temperature
# Mean: 10.535898132566903
# Variance: 144.23511572311804
# Skewness: 0.7851041286298612
# Kurtosis: 2.0037766043100795
#
# Column: Rotor_Speed
# Mean: 58.86654011704192
# Variance: 913.6061125377275
# Skewness: 0.7792384067691649
# Kurtosis: 2.383054651350908
#
# Column: Nacelle_temperature
# Mean: 14.002058106160817
# Variance: 120.11609352875982
# Skewness: -0.0022453594524931126
# Kurtosis: -1.2987634867694902
#
# Column: Bearing_temperature
# Mean: 16.01217301554623
# Variance: 124.70063245188074
# Skewness: -0.006273220298973359
# Kurtosis: -1.196090871301495
#
# Column: Generator_speed
# Mean: 70.68938088031373
# Variance: 1441.6560906790535
# Skewness: 0.7711029486746276
# Kurtosis: 2.4586370281653265
#
# Column: Yaw_angle
# Mean: 0.5093620249951565
# Variance: 2690.232937508962
# Skewness: 0.002120142177245951
# Kurtosis: -1.1978645748015173
#
# Column: Wind_direction
# Mean: 180.20438514136396
# Variance: 10718.88627674634
# Skewness: -0.003044242610164019
# Kurtosis: -1.189435110817113
#
# Column: Wheel_hub_temperature
# Mean: 16.98520149841779
# Variance: 119.94702513243595
# Skewness: 0.001998230930775534
# Kurtosis: -1.3042941235355365
#
# Column: Gear_box_inlet_temperature
# Mean: 14.962365506064389
# Variance: 120.20628967180147
# Skewness: 0.0032132964339942997
# Kurtosis: -1.306595155223085

# %% [markdown]
# # Histogram for all numeric columns

# %%
for col in numeric_columns:
    plt.figure()
    plt.hist(df[col], bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
df.dtypes
# Out:
# Wind_speed                       float64
# Power                            float64
# Nacelle_ambient_temperature      float64
# Generator_bearing_temperature    float64
# Gear_oil_temperature             float64
# Ambient_temperature              float64
# Rotor_Speed                      float64
# Nacelle_temperature              float64
# Bearing_temperature              float64
# Generator_speed                  float64
# Yaw_angle                        float64
# Wind_direction                   float64
# Wheel_hub_temperature            float64
# Gear_box_inlet_temperature       float64
# dtype: object

# %%
plt.figure(figsize=(12, 6))
plt.boxplot(df['Wind_speed'])
plt.title("Boxplots for All Numeric Columns")
plt.xticks(rotation=45)
plt.show()
